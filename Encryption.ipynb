# %% [markdown]
# Encrytion problem:

# %%
#provide the code that will encrypt the msg then descrypt it

print(ord('a'))   #convert  letter to number
print(chr(97))     #convert  num to letter
# Out:
# 97
# a

# %%
message="Encrypt this message using python!"
encrypted_message=""
for i in message.lower():
 if i.isalpha():
   encrypted_message+=chr(219-ord(i))
 elif i==" ":
   encrypted_message+="**"
 else:
  encrypted_message+=i
print(encrypted_message)
# Out:
# vmxibkg**gsrh**nvhhztv**fhrmt**kbgslm!

# %%
print(chr(219))
# Out:
# Û

# %%
print(ord('n'))
# Out:
# 110

# %%
219-110
# Out:
# 109

# %%
#printing aschi values of characters in a mess

x="sbcd efg"
for i in x:
 if type(i)==str:
   y=ord(i)
 print(y)
# Out:
# 115
# 98
# 99
# 100
# 32
# 101
# 102
# 103

# %%
print(ord('s'))
# Out:
# 115
