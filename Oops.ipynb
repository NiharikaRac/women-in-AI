# %%
#python is a object oriented
class Employee:    #class
  comp="Dell"
  dept="WIAI"

# %%
x=Employee ()  # x is the object name
print(x.comp)   #accessing using object
# Out:
# Dell

# %%
print(x.dept)
# Out:
# WIAI

# %%
x.comp="Google"   #assigning new value(changing the value for comp)

# %%
x.comp
# Out:
# 'Google'

# %%
y=Employee()   #another object   (changes made using previous objects is not reflected)

# %%
y.comp
# Out:
# 'Dell'

# %%
class Employee:    #class
  comp="Dell"
  dept="WIAI"

  def wish(self):     #self is a class  , no need of arguments
    print("Good Morning")
  def add(self,a,b):
    return(a+b)

# %%
x=Employee()

# %%
x.wish()
# Out:
# Good Morning

# %%
x.wish()    #doesnt take arguments
# Out:
# Good Morning

# %%
x.add(1,2)
# Out:
# 3

# %%
x.dept
# Out:
# 'WIAI'

# %%
class Employee:    #class
  comp="Dell"
  dept="WIAI"

  def __init__(self,name):              #__init__                                           #self is needed to initialize the classs
    print(f"{name},welcometo LLF")
                                   #self is the keyword which links the function with class
  def wish(self):     #self is a class
    print("Good Morning")
  def add(self,a,b):
    return(a+b)

# %%
Employee("Ramu")
# Out:
# Ramu,welcometo LLF

# %%
x=Employee("Ram")
# Out:
# Ram,welcometo LLF

# %%
class Employee:    #class
  comp="Dell"
  dept="WIAI"

  def wish(self):     #self is a class
    print("Good Morning")
  def add(self,a,b):
    return(a+b)

class Employee2:
  comp="Googlw"
  location="Delhi"

  def add(self,a,b):
    return(a**2+b**2)

# %%
x=Employee()

# %%
y=Employee2()

# %%
x.add(2,3)
# Out:
# 5

# %%
y.add(2,3)
# Out:
# 13

# %%
x.wish()
# Out:
# Good Morning

# %% [markdown]
# create a class with name classroom,add function to add new students or remove students and
# add function to collect email id/contact details

# %%
class classroom:
   def __init__(self,name):
    self.students=[]
   def student_list(self,name):
    return(student_list)


   def __init__(self,contacts):
    self.contacts=[]
   def contact(self,email_id):
    return(contact)

# %%
c=classroom()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-52a0cdc688ac> in <cell line: 1>()
# ----> 1 c=classroom()
#
# TypeError: classroom.__init__() missing 1 required positional argument: 'contact'

# %%
c.contact
# Out:
# []

# %%
c.contact("prasthy@gmail.com")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-5a24b42da503> in <cell line: 1>()
# ----> 1 c.contact("prasthy@gmail.com")
#
# TypeError: 'list' object is not callable

# %%
c.student_list
# Out:
# <bound method classroom.student_list of <__main__.classroom object at 0x7b7b340dece0>>

# %%
c.student_list("Ram")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-5993bca8b115> in <cell line: 1>()
# ----> 1 c.student_list("Ram")
#
# <ipython-input-61-11ba6a452535> in student_list(self, name)
#       3     self.students=[]
#       4    def student_list(self,name):
# ----> 5     return(students)
#       6
#       7
#
# NameError: name 'students' is not defined

# %%
#1                                                 we can create our own libraries like pandas in this way
class classroom:
  def __init__(self):
    self.students=[]
    self.contacts=[]
  def add_student(self,name):
    s=name
    self.students.append(s)
  def add_contact(self,email_id):
    e=email_id
    self.contacts.append(e)

# %%
c=classroom()

# %%
c.add_student("Ram")

# %%
c.students
# Out:
# ['Ram']

# %%
c.add_contact("ram123@gmail.com")

# %%
c.contacts
# Out:
# ['ram123@gmail.com']

# %%
#2
class classroom:
  def __init__(self):
    self.students=[]
    self.contacts=[]
  def add_student(self,name):
    s=name
    self.students.append(s)
  def add_contact(self,email_id):
    e=email_id
    self.contacts.append(e)
  def remove_stud(self,name):              #def remove_stud(self,name):
self.students.remove(name)                 #    for std in students:
                                           #        if std[0]==name:
                                           #            self.students.remove(std)
                                           #            break

# %%
a=classroom()

# %%
a.add_student("ram")

# %%
a.add_student("rani")

# %%
a.add_contact("ram@gmail.com")

# %%
a.add_contact("rani@gmail.com")

# %%
a.students
# Out:
# ['ram', 'rani']

# %%
a.contacts
# Out:
# ['ram@gmail.com', 'rani@gmail.com']

# %%
a.remove_stud("ram")

# %%
a.students
# Out:
# ['rani']

# %% [markdown]
# create a shopping cart app which will take the items and give total bill to the customer

# %%
#1
class shopping:
  def __init__(self):
    self.items=[]
    self.cost=[]
  def shop_items(self,item):
    s=item
    self.items.append(s)
  def cost_item(self,b):
    c=b
    self.cost.append(c)

  def total_bill(self):
    return(sum(self.cost))

# %%
x=shopping()

# %%
x.shop_items("pen")

# %%
x.shop_items("pencil")

# %%
x.cost_item(3)

# %%
x.cost_item(5)

# %%
x.items
# Out:
# ['pen', 'pencil']

# %%
x.cost
# Out:
# [3, 5]

# %%
x.total_bill()
# Out:
# 8

# %%
#1(2)
class shopping:
  def __init__(self):
    self.items=[]
    self.cost=[]
  def shop_items(self,item):
    s=item
    self.items.append(s)
  def cost_item(self,b):
    c=b
    self.cost.append(c)

  def total_bill(self):
    total=0
    for i in self.cost:
      total=total+i
    return(total)

# %%
x=shopping()

# %%
x.shop_items("watch")

# %%
x.shop_items("cap")

# %%
x.items
# Out:
# ['watch', 'cap']

# %%
x.cost_item(100)

# %%
x.cost_item(200)

# %%
x.cost
# Out:
# [100, 200]

# %%
x.total_bill()
# Out:
# 300
